# %%
password = "W@12"

name = input("Please enter your name : ")

if name == "Ahmet":
    print("Hello, Ahmet! The password is :", password)
else:
    print(f"Hello {name}! See you later.")
# Out:
# Please enter your name : Ahmet
# Hello, Ahmet! The password is : W@12
