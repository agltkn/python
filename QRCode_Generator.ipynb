# %%
#pip install pyqrcode
#pip install pypng
import pyqrcode
import png
link = input("Please enter text ")
qr_code = pyqrcode.create(link)
qr_code.png("qrcode.png", scale=20)
# Out:
# Please enter text mehmet doksal

# %%
pip install pypng
# Out:
# ...
#      ---------------------------------------- 58.1/58.1 kB 1.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
